# %% [markdown]
# <a href="https://colab.research.google.com/github/HoPhuocMinhQuan20104052/HoPhuocMinhQuan/blob/main/Excel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from openpyxl import Workbook
wb= Workbook()
sheet=wb.active
sheet['A1']='Minh Quan'
sheet['B1']='Quan Manh'
sheet['A2']='Manh Tai'
wb.save('/content/Excel.xlsx')

# %%
import openpyxl
from openpyxl import Workbook
wb=openpyxl.load_workbook('/content/Excel.xlsx')
sheet=wb.active
t1=sheet['A1']
t2=sheet['B1']
t3=sheet.cell(row=2,column=1)
t4=sheet.cell(row=2,column=2)
print(t1.value,t2.value)
print(t3.value,t4.value)
# Out:
# Minh Quan Quan Manh
# Manh Tai None

# %%
import openpyxl
my_wb=openpyxl.Workbook()
my_sheet=my_wb.active
c1=my_sheet.cell(row=1, column= 1)
c1.value= 'Ho Phuoc Minh Quan'
c2=my_sheet.cell(row=1, column=2)
c2.value='Nguyen Quan Manh'
c3=my_sheet['A2']
c3.value='Bac Lieu'
c4=my_sheet['B2']
c4.value='Hoc Mon'
my_wb.create_sheet(index = 1, title ='Co Khi May')
my_wb.save('/content/Excel.xlsx')

# %%
import openpyxl
my_path= '/content/Excel.xlsx'
my_wb_obj= openpyxl.load_workbook(my_path)
my_sheet_obj= my_wb_obj.active
print(my_sheet_obj.max_row)
My_wb_obj = openpyxl.load_workbook(my_path)
sheet_obj=My_wb_obj.active
print(sheet_obj.max_column)
my_cell_obj=my_sheet_obj.cell(row=1, column=1)
print(my_cell_obj.value)
my_max_col = my_sheet_obj.max_column
for i in range(1,my_max_col +1):
  my_cell_obj = my_sheet_obj.cell(row=1,column=i)
  print(my_cell_obj.value)
my_row = my_sheet_obj.max_row
for i in range(1,my_row +1):
  cell_obj = my_sheet_obj.cell(row=i,column=1)
  print(cell_obj.value)
for i in range(1,my_max_col+1):
  cell_obj=my_sheet_obj.cell(row=2, column=i)
  print(cell_obj.value, end=' ')
# Out:
# 2
# 2
# Ho Phuoc Minh Quan
# Ho Phuoc Minh Quan
# Nguyen Quan Manh
# Ho Phuoc Minh Quan
# Bac Lieu
# Bac Lieu Hoc Mon

# %%
import matplotlib.pyplot as plt 
import numpy as np
x=np.arange(6)
y=x+1
plt.plot(x,y,'o--')
plt.show()

# %%
plt.plot(x,y,'o--')
plt.plot(x,-y,'o--')
plt.title('y=x and y=-x')
plt.xlabel('x')
plt.ylabel('y')
#plt.axis('off')
plt.grid('on')
plt.show()

# %%
N=16
x=np.linspace(0,15,16)
y=x
plt.plot(x,y,'o--')
plt.axis('off')
plt.show()

# %%
x=np.linspace(0,15,16)
y=np.logspace(0.1,2,16)
plt.plot(x,y,'--o')
plt.show()

# %%
x=[4,5,3,1,6,7]
plt.plot(x)
plt.show()

# %%
x=np.arange(25)
plt.plot(x)
plt.show()

# %%
x=np.arange(25)
plt.plot(x,x**3+1)
plt.show()

# %%
x=np.arange(7)
plt.plot(x,-x**2,'-')
plt.plot(x,-x**3,'--')
plt.plot(x,-2*x,'-.')
plt.plot(x,-2**x,':')
#plt.plot(x,-x**2,'-',x,-x**3,'--',x,-2*x,'-.',x,-2**x,':')
plt.grid(True)
plt.savefig('test.png')
plt.show()

# %%
x=np.arange(3)
plt.subplots_adjust(wspace=0.3,hspace=0.3)
plt.subplot(2,2,1)
plt.plot(x,-x**2,color='g')
plt.subplot(2,2,2)
plt.plot(x,-x**3,color='r')
plt.subplot(2,2,3)
plt.plot(x,-2*x,color='b')
plt.subplot(2,2,4)
plt.plot(x,-2**x,color='y')
plt.show()

# %%
plt.axis([0,150,0,100])
plt.scatter(60,50,s=1000,color='b',alpha=1)
plt.scatter(80,50,s=1000,color='b',alpha=.5)
plt.scatter(100,50,s=1000,color='b',alpha=.1)
plt.show()

# %%
plt.plot([1,2],[3,4],linewidth=5,color='r')
plt.text(1,3,'a')
plt.arrow(1,3,1,1,head_length=2,head_width=2,color='g')
plt.show()

# %%
plt.plot([30,30],[30,0],linewidth=5,color='r')
plt.text(29,15,'mui ten')
plt.arrow(30,30,0,-30,head_length=4,head_width=2,color='g')
plt.show()

# %%
x=np.arange(4)
y=np.random.rand(4)
plt.bar(x,y)
plt.show()

# %%
y=np.random.rand(3,4)
plt.bar(x+0,y[0],color='b',width=0.25)
plt.bar(x+0.25,y[1],color='y',width=0.25)
plt.bar(x+0.5,y[2],color='r',width=0.25)
plt.show()

# %%
x=np.arange(4)
y=np.random.rand(4)
plt.barh(x,y)
plt.show()

# %%
N=1000
x=np.random.rand(N)
y=np.random.rand(N)
colors=np.random.rand(N)
size=100
plt.scatter(x,y,s=size,c=colors,alpha=1)
plt.show()
