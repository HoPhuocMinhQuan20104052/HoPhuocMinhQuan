# %% [markdown]
# <a href="https://colab.research.google.com/github/HoPhuocMinhQuan20104052/HoPhuocMinhQuan/blob/main/Week_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
with open('text.txt',mode='w') as accounts:
  accounts.write('1 Nguyen Van A 8.0\n')
  accounts.write('2 Le Thi B 6.8\n')
with open('text1.txt',mode='w') as accounts:
  print('7:00 Nguyen Van A',file =accounts)
  print('7:01 Le Thi B', file = accounts)

# %%
import pandas as pd
url='/content/Book3.csv'
dataframe = pd.read_csv(url)
dataframe.head(5)
# Out:
#    NO  Student ID Full Name  Score Faculty  Year
# 0   1    20104010       Tai     10     CKM    20
# 1   2    20104041      Manh     10     CKM    20
# 2   3    20104052      Quan     10     CKM    20
# 3   4    20104015       Anh     10     CKM    20
# 4   5    20149564      Vinh      9     CLC    20

# %%
import pandas as pd
url = '/content/Book3.csv'
dataframe = pd.read_csv(url)
dataframe.head(10)
dataframe [:4]
dataframe = dataframe.set_index (dataframe['Full Name'])
dataframe.loc ['Quan']
# Out:
# NO                   3
# Student ID    20104052
# Full Name         Quan
# Score               10
# Faculty            CKM
# Year                20
# Name: Quan, dtype: object

# %%
import pandas as pd
url = '/content/Book3.csv'
dataframe = pd.read_csv(url)
dataframe.head(10)
dataframe[:4]
dataframe = dataframe.set_index(dataframe['Faculty'])
dataframe.loc['CLC']
dataframe[(dataframe['Faculty']=='CKM') & (dataframe['Score']>=2)]
# Out:
#          NO  Student ID Full Name  Score Faculty  Year
# Faculty
# CKM       1    20104010       Tai     10     CKM    20
# CKM       2    20104041      Manh     10     CKM    20
# CKM       3    20104052      Quan     10     CKM    20
# CKM       4    20104015       Anh     10     CKM    20
# CKM       9    20156753     Duong     10     CKM    18
# CKM      10    20185249     Hoang     10     CKM    20

# %%
import pandas as pd
url = '/content/Book3.csv'
dataframe = pd.read_csv(url)
dataframe.head(10)
dataframe['Faculty'].unique()
# Out:
# array(['CKM', 'CLC', 'XD', 'CNM'], dtype=object)

# %%
import pandas as pd
url = '/content/Book3.csv'
dataframe = pd.read_csv(url)
dataframe.head(10)
dataframe['Faculty'].value_counts()
# Out:
# CKM    6
# CLC    2
# CNM    2
# XD     1
# Name: Faculty, dtype: int64

# %%
import pandas as pd
url = '/content/Book3.csv'
dataframe = pd.read_csv(url)
dataframe.drop('Faculty',axis=1).head(10)
# Out:
#    NO  Student ID Full Name  Score  Year
# 0   1    20104010       Tai     10    20
# 1   2    20104041      Manh     10    20
# 2   3    20104052      Quan     10    20
# 3   4    20104015       Anh     10    20
# 4   5    20149564      Vinh      9    20
# 5   6    20132567       Huy     10    19
# 6   7    20156548     Khang      9    19
# 7   8    20165483      Kien      8    20
# 8   9    20156753     Duong     10    18
# 9  10    20185249     Hoang     10    20

# %%
import pandas as pd
url = '/content/Book3.csv'
dataframe = pd.read_csv(url)
dataframe.groupby('Score').count()
# Out:
#        NO  Student ID  Full Name  Faculty  Year
# Score
# 7       1           1          1        1     1
# 8       1           1          1        1     1
# 9       2           2          2        2     2
# 10      7           7          7        7     7

# %%
import pandas as pd
url = '/content/Book3.csv'
dataframe = pd.read_csv(url)
dataframe.groupby('Score').mean()
# Out:
#          NO  Student ID       Year
# Score
# 7      11.0  20194523.0  19.000000
# 8       8.0  20165483.0  20.000000
# 9       6.0  20153056.0  19.500000
# 10      5.0  20127241.0  19.571429

# %%
import pandas as pd
url='http://winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
data
# Out:
#       Year      City       Sport      Discipline  NOC            Event  \
# 0     1924  Chamonix     Skating  Figure skating  AUT       individual
# 1     1924  Chamonix     Skating  Figure skating  AUT       individual
# 2     1924  Chamonix     Skating  Figure skating  AUT            pairs
# 3     1924  Chamonix   Bobsleigh       Bobsleigh  BEL         four-man
# 4     1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# ...    ...       ...         ...             ...  ...              ...
# 2306  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2307  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2308  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2309  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
# 2310  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
#
#      Event gender   Medal
# 0               M  Silver
# 1               W    Gold
# 2               X    Gold
# ...

# %%
from typing import Counter
import pandas as pd
url='http://winterolympicsmedals.com/medals.csv'
data=pd.read_csv(url)
data.groupby(['Event gender','NOC']).count()
# Out:
#                   Year  City  Sport  Discipline  Event  Medal
# Event gender NOC
# M            AUS     3     3      3           3      3      3
#              AUT   118   118    118         118    118    118
#              BEL     4     4      4           4      4      4
#              BLR     5     5      5           5      5      5
#              BUL     1     1      1           1      1      1
# ...                ...   ...    ...         ...    ...    ...
# X            ITA     8     8      8           8      8      8
#              RUS    12    12     12          12     12     12
#              UKR     1     1      1           1      1      1
#              URS    21    21     21          21     21     21
#              USA    11    11     11          11     11     11
#
# [96 rows x 6 columns]

# %%
import pandas as pd
url = 'http://winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
data = data.set_index(data['Medal'])
data.loc['Gold']
data[(data['Medal']=='Gold') & (data['Event gender']=='M') & (data['NOC']=='USA')]
# Out:
#        Year                    City       Sport      Discipline  NOC  \
# Medal
# Gold   1924                Chamonix     Skating   Speed skating  USA
# Gold   1928              St. Moritz   Bobsleigh       Bobsleigh  USA
# Gold   1928              St. Moritz   Bobsleigh        Skeleton  USA
# Gold   1932             Lake Placid   Bobsleigh       Bobsleigh  USA
# Gold   1932             Lake Placid   Bobsleigh       Bobsleigh  USA
# Gold   1932             Lake Placid     Skating   Speed skating  USA
# Gold   1932             Lake Placid     Skating   Speed skating  USA
# Gold   1932             Lake Placid     Skating   Speed skating  USA
# Gold   1932             Lake Placid     Skating   Speed skating  USA
# Gold   1936  Garmisch-Partenkirchen   Bobsleigh       Bobsleigh  USA
# Gold   1948              St. Moritz   Bobsleigh       Bobsleigh  USA
# Gold   1948              St. Moritz     Skating  Figure skating  USA
# ...
