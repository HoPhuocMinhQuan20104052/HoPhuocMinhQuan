# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl 
food = ctrl.Antecedent(np.arange(0,11,1),'food')
service = ctrl.Antecedent(np.arange(0,11,1),'service')
tip = ctrl.Consequent(np.arange(10,26,1),'tip')
food['poor']=fuzz.trimf(food.universe,[0,0,5])
food['average']=fuzz.trimf(food.universe,[0,5,10])
food['good']=fuzz.trimf(food.universe,[5,10,10])
service['poor']=fuzz.trimf(service.universe,[0,0,5])
service['average']=fuzz.trimf(service.universe,[0,5,10])
service['good']=fuzz.trimf(service.universe,[5,10,10])
tip['less']=fuzz.trimf(tip.universe,[10,14,18])
tip['normal']=fuzz.trimf(tip.universe,[14,18,22])
tip['much']=fuzz.trimf(tip.universe,[18,22,25])
service.view()
food.view()
tip.view()
rule1 = ctrl.Rule(food['poor'] & service['poor'], tip['less'])
rule2 = ctrl.Rule(food['poor'] & service['average'], tip['less'])
rule3 = ctrl.Rule(food['poor'] & service['good'], tip['normal'])
rule4 = ctrl.Rule(food['average'] & service['average'], tip['normal'])
rule5 = ctrl.Rule(food['average'] & service['good'], tip['normal'])
rule6 = ctrl.Rule(food['average'] & service['poor'], tip['less'])
rule7 = ctrl.Rule(food['good'] & service['good'], tip['much'])
rule8 = ctrl.Rule(food['good'] & service['average'], tip['much'])
rule9 = ctrl.Rule(food['good'] & service['poor'], tip['normal'])
tipping_ctrl = ctrl.ControlSystem([rule1,rule2,rule3,rule4,rule5,rule6,rule7,rule8,rule9])
tipping =ctrl.ControlSystemSimulation(tip)
tipping.input['food']=6.2
tipping.input['service']=3.5
tipping.compute()
print(tipping.output['tip'])
tip.view(sim =tipping)
# Out:
# 17.516163602679207

# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl 
time = ctrl.Antecedent(np.arange(10,121,1),'time')
rice = ctrl.Antecedent(np.arange(100,1001,1),'rice')
power = ctrl.Consequent(np.arange(0,101,1),'power')
time['rat nhanh']=fuzz.trimf(time.universe,[10,10,32])
time['nhanh']=fuzz.trimf(time.universe,[10,32,54])
time['hoi nhanh']=fuzz.trimf(time.universe,[32,54,76])
time['vua']=fuzz.trimf(time.universe,[54,76,98])
time['cham']=fuzz.trimf(time.universe,[76,98,120])
time['rat cham']=fuzz.trimf(time.universe,[98,120,120])
rice['rat it']=fuzz.trimf(rice.universe,[100,100,280])
rice['it']=fuzz.trimf(rice.universe,[100,280,460])
rice['vua']=fuzz.trimf(rice.universe,[280,460,640])
rice['hoi nhieu']=fuzz.trimf(rice.universe,[460,640,820])
rice['nhieu']=fuzz.trimf(rice.universe,[640,820,1000])
rice['rat nhieu']=fuzz.trimf(rice.universe,[820,1000,1000])
power['rat nho']=fuzz.trimf(power.universe,[0,20,30])
power['nho']=fuzz.trimf(power.universe,[20,30,40])
power['vua']=fuzz.trimf(power.universe,[30,40,50])
power['lon']=fuzz.trimf(power.universe,[40,50,70])
power['rat lon']=fuzz.trimf(power.universe,[50,70,100])
time.view()
rice.view()
power.view()
rule1 = ctrl.Rule(time['rat cham'] & rice['rat it'], power['rat nho'])
rule2 = ctrl.Rule(time['rat cham'] & rice['it'], power['rat nho'])
rule3 = ctrl.Rule(time['rat cham'] & rice['vua'], power['nho'])
rule4 = ctrl.Rule(time['rat cham'] & rice['hoi nhieu'], power['vua'])
rule5 = ctrl.Rule(time['rat cham'] & rice['nhieu'], power['lon'])
rule6 = ctrl.Rule(time['rat cham'] & rice['rat nhieu'], power['rat lon'])
rule7 = ctrl.Rule(time['cham'] & rice['rat it'], power[ 'nho'])
rule8 = ctrl.Rule(time['cham'] & rice['it'], power['nho'])
rule9 = ctrl.Rule(time['cham'] & rice['vua'], power['vua'])
rule10 = ctrl.Rule(time['cham'] & rice['hoi nhieu'], power['vua'])
rule11 = ctrl.Rule(time['cham'] & rice['nhieu'], power['lon'])
rule12 = ctrl.Rule(time['cham'] & rice['rat nhieu'], power['rat lon'])
rule13 = ctrl.Rule(time['vua'] & rice['rat it'], power['nho'])
rule14 = ctrl.Rule(time['vua'] & rice['it'], power['vua'])
rule15 = ctrl.Rule(time['vua'] & rice['vua'], power['vua'])
rule16 = ctrl.Rule(time['vua'] & rice['hoi nhieu'], power['lon'])
rule17 = ctrl.Rule(time['vua'] & rice['nhieu'], power['rat lon'])
rule18 = ctrl.Rule(time['vua'] & rice['rat nhieu'], power['rat lon'])
rule19 = ctrl.Rule(time['hoi nhanh'] & rice['rat it'], power['nho'])
rule20 = ctrl.Rule(time['hoi nhanh'] & rice['it'], power['vua'])
rule21 = ctrl.Rule(time['hoi nhanh'] & rice['vua'], power['lon'])
rule22 = ctrl.Rule(time['hoi nhanh'] & rice['hoi nhieu'], power['lon'])
rule23 = ctrl.Rule(time['hoi nhanh'] & rice['nhieu'], power['rat lon'])
rule24 = ctrl.Rule(time['hoi nhanh'] & rice['rat nhieu'], power['rat lon'])
rule25 = ctrl.Rule(time['nhanh'] & rice['rat it'], power['vua'])
rule26 = ctrl.Rule(time['nhanh'] & rice['it'], power['vua'])
rule27 = ctrl.Rule(time['nhanh'] & rice['vua'], power['lon'])
rule28 = ctrl.Rule(time['nhanh'] & rice['hoi nhieu'], power['lon'])
rule29 = ctrl.Rule(time['nhanh'] & rice['nhieu'], power['rat lon'])
rule30 = ctrl.Rule(time['nhanh'] & rice['rat nhieu'], power['rat lon'])
rule31 = ctrl.Rule(time['rat nhanh'] & rice['rat it'], power['vua'])
rule32 = ctrl.Rule(time['rat nhanh'] & rice['it'], power['lon'])
rule33 = ctrl.Rule(time['rat nhanh'] & rice['vua'], power['lon'])
rule34 = ctrl.Rule(time['rat nhanh'] & rice['hoi nhieu'], power['rat lon'])
rule35 = ctrl.Rule(time['rat nhanh'] & rice['nhieu'], power['rat lon'])
rule36 = ctrl.Rule(time['rat nhanh'] & rice['rat nhieu'], power['rat lon'])
powering_ctrl = ctrl.ControlSystem([rule1,rule2,rule3,rule4,rule5,rule6,rule7,rule8,rule9,rule10,rule11,rule12,rule13,rule14,rule15,rule16,rule17,rule18,rule19,rule20,rule21,rule22,rule23,rule24,rule25,rule26,rule27,rule28,rule29,rule30])
powering = ctrl.ControlSystemSimulation(powering_ctrl)
powering.input['time']=450
powering.input['rice']=300
powering.compute()
print(powering.output['power'])
power.view(sim =powering)
# Out:
# 17.87585818924938

# %%
pip install -U scikit-fuzzy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 993 kB 41.7 MB/s
# ...
#   Created wheel for scikit-fuzzy: filename=scikit_fuzzy-0.4.2-py3-none-any.whl size=894089 sha256=0d551c7f1740f07601afb7cabf95a2990ce6cc54a93d6d32d09d8c0a9489929a
#   Stored in directory: /root/.cache/pip/wheels/d5/74/fc/38588a3d2e3f34f74588e6daa3aa5b0a322bd6f9420a707131
# Successfully built scikit-fuzzy
# ...
